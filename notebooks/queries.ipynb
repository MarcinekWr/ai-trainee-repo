# %%
# Zapytanie (embedding): O czym jest ten dokument?
vector_results = [
  {
    "id": "7a794b38-31a1-457f-a4bb-2960fd659abe",
    "content": "Located at the southern tip of the state of \nNew York, the city is the center of the New York \nmetropolitan area, one of the most populous urban \nagglomerati ons in the world.  A global power city, New York \nCity exerts a significant impact upon commerce, finance, \nmedia, art, fashion, research, technology, education, and \nentertainment, its fast pace defining the term New York \nminute.",
    "@search.score": 0.01666666753590107,
    "@search.reranker_score": null,
    "@search.highlights": null,
    "@search.captions": null
  },
  {
    "id": "73e76c8a-f2af-4f26-9c52-e652f0a84e7b",
    "content": "Home to the headquarters of t he United Nations, \nNew York is an important center for international diplomacy \nand has been described as the cultural and financial capital \nof the world .  \n \nNew York  Hotels  \nMargie’s Travel offers the following accommodation options \nin New York : \nThe Manhattan  Hotel  \nStay in the heart of New York City, within an easy walk to \nTimes Square and Broadway .  \nThe Grand Central  Hotel  \nComfortable mid -town  hotel .",
    "@search.score": 0.016393441706895828,
    "@search.reranker_score": null,
    "@search.highlights": null,
    "@search.captions": null
  },
  {
    "id": "f9ac02a9-642d-4888-9609-5942c351ef7d",
    "content": "Close to Grand Central \nStation, the Chrysler Building, and the Empire State \nBuilding.   \nThe Park  Hotel  \nLuxurious accommodation  in upper Manhattan,  with views \nof Central Park .  \n \n \nTo book your trip to New York , visit www. margiestravel. com  \n \n\n.",
    "@search.score": 0.016129031777381897,
    "@search.reranker_score": null,
    "@search.highlights": null,
    "@search.captions": null
  }
]
print("Vector search results:", vector_results)

answer = """Ten dokument opisuje Nowy Jork jako globalne miasto o dużym znaczeniu w dziedzinach takich jak handel, finanse, media, sztuka, moda, badania, technologia, edukacja i rozrywka. Wspomina również, że Nowy Jork jest siedzibą Organizacji Narodów Zjednoczonych i ważnym centrum międzynarodowej dyplomacji, określanym jako kulturalna i finansowa stolica świata. W dalszej części dokumentu przedstawiono oferty hotelowe w Nowym Jorku, dostępne za pośrednictwem firmy Margie’s Travel, w tym trzy konkretne opcje zakwaterowania: The Manhattan Hotel, The Grand Central Hotel oraz The Park Hotel. Na końcu podano stronę internetową, na której można dokonać rezerwacji."""
print("RAG answer (vector-based):", answer)

# %%
# Zapytanie: Tell me about New York
semantic_results = [
  {
    "id": "8c38d4da-9877-4dfa-bf0f-25cf21dada98",
    "content": "Margie’s Travel Presents…  \nNew York  \nThe City of New York, often called New York City or simply \nNew York, is the most populous city in the United States.  \nWith an estimated 2015 population of 8,550,405 distributed \nover a land area of about 302. 6 square miles, New York \nCity is also the most densely populated major city in the \nUnited States.",
    "@search.score": 1.2955798,
    "@search.reranker_score": 2.7131919860839844,
    "@search.highlights": null,
    "@search.captions": null
  },
  {
    "id": "34bc64ae-7951-442d-bed4-adef22987d75",
    "content": "Located at the southern tip of the state of \nNew York, the city is the center of the New York \nmetropolitan area, one of the most populous urban \nagglomerati ons in the world.  A global power city, New York \nCity exerts a significant impact upon commerce, finance, \nmedia, art, fashion, research, technology, education, and \nentertainment, its fast pace defining the term New York \nminute.",
    "@search.score": 0.9710255,
    "@search.reranker_score": 2.6529321670532227,
    "@search.highlights": null,
    "@search.captions": null
  },
  {
    "id": "212cec2a-9673-45c9-9ab1-95392b9aa222",
    "content": "Home to the headquarters of t he United Nations, \nNew York is an important center for international diplomacy \nand has been described as the cultural and financial capital \nof the world .  \n \nNew York  Hotels  \nMargie’s Travel offers the following accommodation options \nin New York : \nThe Manhattan  Hotel  \nStay in the heart of New York City, within an easy walk to \nTimes Square and Broadway .  \nThe Grand Central  Hotel  \nComfortable mid -town  hotel .",
    "@search.score": 0.942035,
    "@search.reranker_score": 2.2295188903808594,
    "@search.highlights": null,
    "@search.captions": null
  },
  {
    "id": "5d691885-e2d4-4d38-a04b-35b0f23d7e44",
    "content": "Close to Grand Central \nStation, the Chrysler Building, and the Empire State \nBuilding.   \nThe Park  Hotel  \nLuxurious accommodation  in upper Manhattan,  with views \nof Central Park .  \n \n \nTo book your trip to New York , visit www. margiestravel. com  \n \n\n.",
    "@search.score": 0.5236879,
    "@search.reranker_score": 1.89401376247406,
    "@search.highlights": null,
    "@search.captions": null
  }
]
print("Semantic search results:", semantic_results)

answer = """New York, often called New York City or simply New York, is the most populous city in the United States, with an estimated 2015 population of 8,550,405 spread over a land area of about 302.6 square miles. It is also the most densely populated major city in the country. Located at the southern tip of the state of New York, the city serves as the center of the New York metropolitan area, one of the largest urban agglomerations in the world.

New York is known as a global power city, exerting a significant influence on commerce, finance, media, art, fashion, research, technology, education, and entertainment, with its fast pace often referred to as a "New York minute." It is home to the United Nations headquarters, making it a key hub for international diplomacy. Additionally, New York has been described as the cultural and financial capital of the world."""
print("RAG answer:", answer)
